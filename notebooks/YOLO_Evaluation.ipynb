# %% [markdown]
# Load trained model

# %%
import torch

model = torch.hub.load(
    "../models/YOLO/yolov5",
    "custom",
    path="../outputs/yolo/yolov5_mask/weights/best.pt",
    source="local"
)
# Out:
# fatal: cannot change to '/Users/prekshadahal/Desktop/Masters/Year': No such file or directory
# YOLOv5 🚀 2026-1-17 Python-3.13.2 torch-2.9.1 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %% [markdown]
# Run inference on validation images

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("/Users/prekshadahal/Desktop/Masters/Year 2/Computer Vision/Face-Mask Detection/data/yolo/images/val/img_4.jpg")
results = model(img)

results.print()
results.show()
# Out:
# /Users/prekshadahal/Desktop/Masters/Year 2/Computer Vision/Face-Mask Detection/notebooks/../models/YOLO/yolov5/models/common.py:899: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 416x416 1 without_mask
# Speed: 12.4ms pre-process, 190.7ms inference, 4.4ms NMS per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=416x416>

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("/Users/prekshadahal/Desktop/Masters/Year 2/Computer Vision/Face-Mask Detection/data/yolo/images/val/img_19.jpg")
results = model(img)

results.print()
results.show()
# Out:
# /Users/prekshadahal/Desktop/Masters/Year 2/Computer Vision/Face-Mask Detection/notebooks/../models/YOLO/yolov5/models/common.py:899: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 416x416 1 with_mask, 1 without_mask
# Speed: 6.1ms pre-process, 103.2ms inference, 0.5ms NMS per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=416x416>

# %% [markdown]
# Metrics (auto-generated by YOLO)

# %%
import pandas as pd

results_csv = "../outputs/yolo/yolov5_mask/results.csv"
df = pd.read_csv(results_csv)
df.tail()
# Out:
#                 epoch     train/box_loss     train/obj_loss  \
# 25                 25           0.026572           0.014432
# 26                 26           0.025475           0.014672
# 27                 27           0.025458           0.014411
# 28                 28           0.024909           0.014300
# 29                 29           0.024761           0.014612
#
#        train/cls_loss  metrics/precision  ...       val/obj_loss  \
# 25           0.002128            0.33207  ...           0.010583
# 26           0.002126            0.34173  ...           0.010633
# 27           0.002040            0.33269  ...           0.010621
# 28           0.001978            0.33813  ...           0.010598
# 29           0.001854            0.34489  ...           0.010609
#
#          val/cls_loss              x/lr0              x/lr1              x/lr2
# 25           0.003210            0.00208            0.00208            0.00208
# ...
