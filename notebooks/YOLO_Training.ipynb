# %% [markdown]
# Setting Up Paths

# %%
import os
import sys
from pathlib import Path

# Base directory
BASE_PATH = Path("/Users/prekshadahal/Desktop/Masters/Year 2/Computer Vision/Face-Mask Detection")

# YOLOv5 repo path
YOLO_PATH = BASE_PATH / "models/YOLO/yolov5"

# Dataset YAML
DATA_YAML = BASE_PATH / "data/yolo/data.yaml"

# Output directory
OUTPUT_DIR = BASE_PATH / "outputs/yolo"

# Add YOLOv5 to sys.path and change working directory
sys.path.append(str(YOLO_PATH))
os.chdir(str(YOLO_PATH))

print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /Users/prekshadahal/Desktop/Masters/Year 2/Computer Vision/Face-Mask Detection/models/YOLO/yolov5

# %% [markdown]
# Verify environment

# %%
import torch

print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("MPS (Apple GPU) available:", torch.backends.mps.is_available())

# Choose device
DEVICE = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
print("Training will run on:", DEVICE)
# Out:
# Torch version: 2.9.1
# CUDA available: False
# MPS (Apple GPU) available: True
# Training will run on: mps

# %% [markdown]
# Verify dataset paths

# %%
# Absolute paths for dataset folders
train_path = BASE_PATH / "data/yolo/images/train"
val_path = BASE_PATH / "data/yolo/images/val"

print("Train folder exists:", train_path.exists())
print("Val folder exists:", val_path.exists())
# Out:
# Train folder exists: True
# Val folder exists: True

# %% [markdown]
# Train YOLOv5

# %%
# Wrap paths in quotes to handle spaces
data_path = f'"{DATA_YAML}"'
project_path = f'"{OUTPUT_DIR}"'
device_str = f'"{DEVICE}"'

# !python train.py \
  --img 640 \
  --batch 16 \
  --epochs 30 \
  --data "/Users/prekshadahal/Desktop/Masters/Year 2/Computer Vision/Face-Mask Detection/data/yolo/data.yaml" \
  --weights yolov5s.pt \
  --project "/Users/prekshadahal/Desktop/Masters/Year 2/Computer Vision/Face-Mask Detection/outputs/yolo" \
  --name yolov5_mask \
  --exist-ok \
  --device mps
# Out:
# train: weights=yolov5s.pt, cfg=, data=/Users/prekshadahal/Desktop/Masters/Year 2/Computer Vision/Face-Mask Detection/data/yolo/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=mps, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=/Users/prekshadahal/Desktop/Masters/Year 2/Computer Vision/Face-Mask Detection/outputs/yolo, name=yolov5_mask, exist_ok=True, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# ...
